# %%
#boolean expression/conditional expression/comparision expression are;
#>
#<
#=
#<=
#>=
#!

# %%
#boolean expression;
a=22
b=55
a<b
# Out:
# True

# %%
a=11
b=33
b>a
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
b<=a
# Out:
# False

# %%
a
