# %%
#data types
#1.numeric
var_int=22
print(var_int)
print(type(var_int))
# Out:
# 22
# <class 'int'>

# %%
var_float=44.6
print(var_float)
print(type(var_float))
# Out:
# 44.6
# <class 'float'>

# %%
var_complex=34+5j
print(var_complex)
print(type(var_complex))
# Out:
# (34+5j)
# <class 'complex'>

# %%
#2.string
var_string="342"
print(var_string)
print(type(var_string))
# Out:
# 342
# <class 'str'>

# %%
#3.boolean
var_int="true"
print(var_int)
print(type(var_int))
# Out:
# true
# <class 'str'>

# %%
#4.sequence/colections
ages=[30,40,50]
print(ages)
print(type(ages))
# Out:
# [30, 40, 50]
# <class 'list'>

# %%
ages=[34,45,56]
print(ages)
print(type(ages))
# Out:
# [34, 45, 56]
# <class 'list'>

# %%
ages=range(6,22)
print(ages)
print(type(ages))
# Out:
# range(6, 22)
# <class 'range'>
