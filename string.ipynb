# %%
text="we are learning python"
letter_string=text[2:1]
print(letter_string)

# %%
text="Apple is a healthy fruit"
letter_string=text[4:15]
print(letter_string)
# Out:
# e is a heal

# %%
text="Father is a banker"
letter_string=text[3:14]
print(letter_string)
# Out:
# her is a ba

# %%
text="enjoy your life with dignity"
letter_string=text[-7]
print(letter_string)
# Out:
# d

# %%
letter_string=text[-12]
print(letter_string)
# Out:
# w

# %%
letter_string=text[14]
print(letter_string)
# Out:
# e
